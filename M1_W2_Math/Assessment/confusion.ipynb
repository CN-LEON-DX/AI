# %%
# 1. Trong confusion matrix:
# TP - Số lượng mẫu positive mô hình dự đoán là positive

# 2. False Negative (FN) trong confusion matrix là gì ?
# FN - Số lượng mẫu negative được dự đoán sai là negative 
# 3. Giả sử chúng ta có một mô hình dự đoán xem email có phải là spam (positive) hay ko. Hãy xác định kết quả sau:
# TP, TN, FN, FP = ?
# - 20 email là spam, nhưng mô hình dự đoán sai là chúng ko phải spam
# - 50 email thực sự ko phải spam và mô hình dự đoán 40 trong số chúng?
# Chọn đáp án đúng: 
# a) TP = 20, TN = 40
# b) TP = 40, FP = 20
# c) FN = 20, TN = 40
# d) TN = 20, FN = 40

# FN = 20 -> TN = 0
# TP = 40 -> FP = 10

# Câu hỏi 4: Giả sử chúng ta có một mô hình dự đoán xem một email có phải là spam (positive) hay
# không (negative). Hãy xác định kết quả sau là TP, TN, FP hay FN, biết rằng:
# - 30 email thật sự không phải spam, nhưng mô hình dự đoán sai rằng chúng là spam.
# - 100 email thật sự là spam và mô hình đúng dự đoán 80 trong số chúng.
# a) TP = 80, TN = 30
# b) TP = 80, FP = 30
# c) TN = 100, FN = 30
# d) FP = 100, FN = 30

# FP = 30
# TP = 80



# Câu hỏi 5: Đầu ra của chương trình sau đây là gì?
# 1 tp = ’true ’
# 2 if type ( tp ) != int: # isinstance (tp , int)
# 3 print (’tp must be int ’)
# a) tp must be int
# b) Không có gì xảy ra
# c) Raise an Error
# d) None

# Câu hỏi 6: Đầu ra của chương trình sau đây là gì?
# 1 fp = 1
# 2 if type ( fp ) != int: # isinstance (fp , int)
# 3 print (’fp must be int ’)

# a) fp must be int
# b) Không có gì xảy ra
# c) Raise an Error
# d) 6

# Câu hỏi 8: Đầu ra của chương trình sau đây là gì?
# 1 tp = 10
# 2 fp = -1
# 3 fn = 1
# 4 if not (( tp > 0) and ( fp > 0) and ( fn > 0) ) :
# 5 print (’tp and fp and fn must be greater than zero ’)
# a) 10
# b) -1
# c) tp and fp and fn must be greater than zero
# d) Raise an Error 

# Câu hỏi 9: Cho TP = 2, TN = 3, FP = 10, FN = 20. Hãy tính giá trị của Precision, Recall, F1-score

# Lưu ý: Kết quả làm tròn đến chữ số thập phân thứ 2.
# a) Precision = 0.17 , Recall = 0.09 , F1-score = 0.12
# b) Precision = 0.09 , Recall = 0.33 , F1-score = 0.99
# c) Precision = 0.22 , Recall = 0.22 , F1-score = 0.22
# d) Precision = 0.00 , Recall = 0.17 , F1-score = 0.22
# Các bạn hãy cài đặt ba hàm compute_precision(), compute_recall(), và compute_f1_score() để lấy
# thông tin trả lời cho câu hỏi trên.
# 1 def compute_precision ( TP , FP ) :
# 2 # ...
# 3 def compute_recall ( TP , FN ) :
# 4 # ...
# 5 def compute_f1_score ( precision , recall ) :
# 6 # ...

def compute_precision(TP, FP):
    return round(TP/(TP + FP), 2)
def compute_recal(TP, FN):
    return round(TP/(TP + FN), 2)
def compute_f1_score(recal, pre):
    return round(2 * (recal * pre)/(recal + pre), 2)

TP = 2
TN = 3
FP = 10
FN = 20
recal = compute_recal(TP, FN)
pre = compute_precision(TP, FP)
print(f'Precision:{pre}, Recal: {recal}, F1_Score: {compute_f1_score(recal, pre)}')
# 1. A
# 2. C
# 3. C
# 4. B
# 5. A
# 6. C
# 7. A
# 8. C
# 9. A
# Out:
# Precision:0.17, Recal: 0.09, F1_Score: 0.12
