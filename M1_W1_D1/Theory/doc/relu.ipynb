# %%
# ReLU - rectified linear func
# relu(x) = x if x > 0 else abs(x)

import numpy as np 
import matplotlib.pyplot as plt
def relu(x):
    return np.maximum(0, x)

x = np.arange(-10, 10, 0.5)
y = relu(x)

plt.plot(x, y)
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
